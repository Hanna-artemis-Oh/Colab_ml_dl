# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/KCC 3기 Colab Home
# Out:
# /content/drive/MyDrive/KCC 3기 Colab Home

# %%
# !git clone https://Hanna-artemis-Oh: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@github.com/Hanna-artemis-Oh/Colab_ml_dl.git
# Out:
# Cloning into 'Colab_ml_dl'...
# ...

# %%
cd /content/drive/MyDrive/KCC 3기 Colab Home/Colab_ml_dl
# Out:
# /content/drive/MyDrive/KCC 3기 Colab Home/Colab_ml_dl

# %%
# !git config --global user.email 'artemiss02@hanmail.net'
# !git config --global user.name 'hanna'

# %%
# !git add "01. Deep Learning 기본 (230727).ipynb"
# Out:
# fatal: pathspec '01. Deep Learning 기본 (230727).ipynb' did not match any files
